# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px

# %%
sns.set_theme(style='whitegrid')
diamond = sns.load_dataset('diamonds')
clarity_ranking = ['I1','SI2','SI1','VS2','VS1','VVS2','VVS1','IF',]

# %%
sns.boxenplot(x='clarity',y='carat',color='b',order=clarity_ranking,scale='linear',data=diamond)
# Out:
# C:\Users\Kashif\AppData\Local\Temp\ipykernel_1264\1944374137.py:1: FutureWarning:
#
# The `scale` parameter has been renamed to `width_method` and will be removed in v0.15. Pass `width_method='linear' for the same effect.
#   sns.boxenplot(x='clarity',y='carat',color='b',order=clarity_ranking,scale='linear',data=diamond)
# <Axes: xlabel='clarity', ylabel='carat'>
